# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\acer\anaconda3\lib\site-packages (from geopandas) (1.1.3)
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp38-cp38-win_amd64.whl (1.0 MB)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20.tar.gz (1.3 MB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\acer\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\acer\\AppData\\Local\\Temp\\pip-install-_e5nbdbz\\fiona\\setup.py'"'"'; __file__='"'"'C:\\Users\\acer\\AppData\\Local\\Temp\\pip-install-_e5nbdbz\\fiona\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\acer\AppData\Local\Temp\pip-pip-egg-info-tplnnfu8'
#          cwd: C:\Users\acer\AppData\Local\Temp\pip-install-_e5nbdbz\fiona\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
conda install geopandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\acer\anaconda3
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py38_0           6 KB
#     anaconda-custom            |           py38_1          36 KB
#     ca-certificates-2021.7.5   |       haa95532_1         113 KB
#     certifi-2021.5.30          |   py38haa95532_0         140 KB
#     click-plugins-1.1.1        |             py_0          12 KB
#     cligj-0.7.2                |   py38haa95532_0          14 KB
#     conda-4.10.3               |   py38haa95532_0         2.9 MB
#     curl-7.71.1                |       h86230a5_2         129 KB
#     expat-2.4.1                |       h6c2663c_2         201 KB
#     fiona-1.8.4                |   py38h22081e2_0         621 KB
#     freexl-1.0.6               |       h2bbff1b_0          51 KB
#     gdal-2.3.3                 |   py38hdf43c64_0         991 KB
#     geopandas-0.6.1            |             py_0         871 KB
#     geos-3.7.1                 |       h33f27b4_0         771 KB
#     gmpy2-2.0.8                |   py38h7edee0f_3         145 KB
#     hdf4-4.2.13                |       h712560f_2         1.3 MB
#     kealib-1.4.7               |       h07cbb95_6         133 KB
#     krb5-1.16.4                |       hc04afaa_0         693 KB
#     libboost-1.73.0            |      h6c2663c_11        20.3 MB
#     libcurl-7.71.1             |       h86230a5_2         275 KB
#     libgdal-2.3.3              |       h10f50ba_0         7.2 MB
#     libkml-1.3.0               |       hd124aa8_5         4.1 MB
#     libllvm9-9.0.1             |       h21ff451_0          61 KB
#     libnetcdf-4.6.1            |       h411e497_2         494 KB
#     libpq-11.2                 |       h3235a2c_0         2.6 MB
#     libspatialite-4.3.0a       |      hc36aec2_19         2.3 MB
#     mpc-1.1.0                  |       h7edee0f_1         260 KB
#     mpfr-4.0.2                 |       h62dcd97_1         1.5 MB
#     mpir-3.0.0                 |       hec2e145_1         1.3 MB
#     munch-2.5.0                |             py_0          15 KB
#     openssl-1.1.1k             |       h2bbff1b_0         4.8 MB
#     pcre-8.45                  |       hd77b12b_0         382 KB
#     proj4-5.2.0                |       ha925a31_1         3.1 MB
#     pyproj-1.9.6               |   py38h6782396_0         234 KB
#     shapely-1.6.4              |   py38h222a598_0         285 KB
#     snappy-1.1.8               |       h33f27b4_0          80 KB
#     tbb-2021.3.0               |       h59b6b97_0         141 KB
#     xerces-c-3.2.3             |       ha925a31_0         2.8 MB
#     ------------------------------------------------------------
#                                            Total:        61.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2020.07-py38_0
#
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2020.11=py38_0
#   - defaults/win-64::astroid==2.4.2=py38_0
#   - defaults/win-64::pylint==2.6.0=py38_0
#   - defaults/noarch::python-language-server==0.35.1=py_0
#   - defaults/win-64::spyder==4.1.5=py38_0
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2020.11=py38_0
#   - defaults/win-64::astroid==2.4.2=py38_0
#   - defaults/win-64::pylint==2.6.0=py38_0
#   - defaults/noarch::python-language-server==0.35.1=py_0
#   - defaults/win-64::spyder==4.1.5=py38_0
#   click-plugins      pkgs/main/noarch::click-plugins-1.1.1-py_0
#   cligj              pkgs/main/win-64::cligj-0.7.2-py38haa95532_0
#   expat              pkgs/main/win-64::expat-2.4.1-h6c2663c_2
#   fiona              pkgs/main/win-64::fiona-1.8.4-py38h22081e2_0
#   freexl             pkgs/main/win-64::freexl-1.0.6-h2bbff1b_0
#   gdal               pkgs/main/win-64::gdal-2.3.3-py38hdf43c64_0
#   geopandas          pkgs/main/noarch::geopandas-0.6.1-py_0
#   geos               pkgs/main/win-64::geos-3.7.1-h33f27b4_0
#   gmpy2              pkgs/main/win-64::gmpy2-2.0.8-py38h7edee0f_3
#   h5py               pkgs/main/win-64::h5py-2.10.0-py38h5e291fa_0
#   hdf4               pkgs/main/win-64::hdf4-4.2.13-h712560f_2
#   kealib             pkgs/main/win-64::kealib-1.4.7-h07cbb95_6
#   libboost           pkgs/main/win-64::libboost-1.73.0-h6c2663c_11
#   libgdal            pkgs/main/win-64::libgdal-2.3.3-h10f50ba_0
#   libkml             pkgs/main/win-64::libkml-1.3.0-hd124aa8_5
#   libllvm9           pkgs/main/win-64::libllvm9-9.0.1-h21ff451_0
#   libnetcdf          pkgs/main/win-64::libnetcdf-4.6.1-h411e497_2
#   libpq              pkgs/main/win-64::libpq-11.2-h3235a2c_0
#   libspatialite      pkgs/main/win-64::libspatialite-4.3.0a-hc36aec2_19
#   mpc                pkgs/main/win-64::mpc-1.1.0-h7edee0f_1
#   mpfr               pkgs/main/win-64::mpfr-4.0.2-h62dcd97_1
#   mpir               pkgs/main/win-64::mpir-3.0.0-hec2e145_1
#   munch              pkgs/main/noarch::munch-2.5.0-py_0
#   pcre               pkgs/main/win-64::pcre-8.45-hd77b12b_0
#   proj4              pkgs/main/win-64::proj4-5.2.0-ha925a31_1
#   pyproj             pkgs/main/win-64::pyproj-1.9.6-py38h6782396_0
#   shapely            pkgs/main/win-64::shapely-1.6.4-py38h222a598_0
#   snappy             pkgs/main/win-64::snappy-1.1.8-h33f27b4_0
#   tbb                pkgs/main/win-64::tbb-2021.3.0-h59b6b97_0
#   wrapt              pkgs/main/win-64::wrapt-1.11.2-py38he774522_0
#   xerces-c           pkgs/main/win-64::xerces-c-3.2.3-ha925a31_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                              2020.10.14-0 --> 2021.7.5-haa95532_1
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> pkgs/main/win-64::certifi-2021.5.30-py38haa95532_0
#   curl                                    7.71.1-h2a8f88b_1 --> 7.71.1-h86230a5_2
#   libcurl                                 7.71.1-h2a8f88b_1 --> 7.71.1-h86230a5_2
#   openssl            conda-forge::openssl-1.1.1h-he774522_0 --> pkgs/main::openssl-1.1.1k-h2bbff1b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              conda-forge::conda-4.10.3-py38haa244f~ --> pkgs/main::conda-4.10.3-py38haa95532_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2020.11-py38_0 --> custom-py38_1
#   krb5                                    1.18.2-hc04afaa_0 --> 1.16.4-hc04afaa_0
#
#
#
# Downloading and Extracting Packages
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# xerces-c-3.2.3       | 2.8 MB    |            |   0%
# xerces-c-3.2.3       | 2.8 MB    | 8          |   8%
# xerces-c-3.2.3       | 2.8 MB    | #4         |  15%
# xerces-c-3.2.3       | 2.8 MB    | ##         |  20%
# xerces-c-3.2.3       | 2.8 MB    | ##5        |  25%
# xerces-c-3.2.3       | 2.8 MB    | ###        |  30%
# xerces-c-3.2.3       | 2.8 MB    | ###5       |  35%
# xerces-c-3.2.3       | 2.8 MB    | ####       |  40%
# xerces-c-3.2.3       | 2.8 MB    | ####5      |  45%
# xerces-c-3.2.3       | 2.8 MB    | #####      |  50%
# xerces-c-3.2.3       | 2.8 MB    | #####4     |  54%
# xerces-c-3.2.3       | 2.8 MB    | #####8     |  59%
# xerces-c-3.2.3       | 2.8 MB    | ######3    |  64%
# xerces-c-3.2.3       | 2.8 MB    | ######8    |  68%
# xerces-c-3.2.3       | 2.8 MB    | #######3   |  73%
# xerces-c-3.2.3       | 2.8 MB    | #######7   |  78%
# xerces-c-3.2.3       | 2.8 MB    | ########2  |  82%
# xerces-c-3.2.3       | 2.8 MB    | ########6  |  87%
# xerces-c-3.2.3       | 2.8 MB    | #########1 |  92%
# xerces-c-3.2.3       | 2.8 MB    | #########6 |  96%
# xerces-c-3.2.3       | 2.8 MB    | ########## | 100%
#
# tbb-2021.3.0         | 141 KB    |            |   0%
# tbb-2021.3.0         | 141 KB    | ########## | 100%
# tbb-2021.3.0         | 141 KB    | ########## | 100%
#
# pcre-8.45            | 382 KB    |            |   0%
# pcre-8.45            | 382 KB    | #####8     |  59%
# pcre-8.45            | 382 KB    | ########## | 100%
#
# freexl-1.0.6         | 51 KB     |            |   0%
# freexl-1.0.6         | 51 KB     | ########## | 100%
#
# libkml-1.3.0         | 4.1 MB    |            |   0%
# libkml-1.3.0         | 4.1 MB    | 5          |   5%
# libkml-1.3.0         | 4.1 MB    | #          |  10%
# libkml-1.3.0         | 4.1 MB    | #4         |  14%
# libkml-1.3.0         | 4.1 MB    | #8         |  18%
# libkml-1.3.0         | 4.1 MB    | ##1        |  22%
# libkml-1.3.0         | 4.1 MB    | ##5        |  25%
# libkml-1.3.0         | 4.1 MB    | ##8        |  29%
# libkml-1.3.0         | 4.1 MB    | ###2       |  32%
# libkml-1.3.0         | 4.1 MB    | ###5       |  35%
# libkml-1.3.0         | 4.1 MB    | ###8       |  39%
# libkml-1.3.0         | 4.1 MB    | ####1      |  42%
# libkml-1.3.0         | 4.1 MB    | ####5      |  45%
# libkml-1.3.0         | 4.1 MB    | ####8      |  48%
# libkml-1.3.0         | 4.1 MB    | #####1     |  52%
# libkml-1.3.0         | 4.1 MB    | #####4     |  55%
# libkml-1.3.0         | 4.1 MB    | #####7     |  58%
# libkml-1.3.0         | 4.1 MB    | ######3    |  63%
# libkml-1.3.0         | 4.1 MB    | ######6    |  67%
# libkml-1.3.0         | 4.1 MB    | #######    |  70%
# libkml-1.3.0         | 4.1 MB    | #######3   |  74%
# libkml-1.3.0         | 4.1 MB    | #######7   |  77%
# libkml-1.3.0         | 4.1 MB    | ########   |  80%
# libkml-1.3.0         | 4.1 MB    | ########3  |  84%
# libkml-1.3.0         | 4.1 MB    | ########6  |  87%
# libkml-1.3.0         | 4.1 MB    | #########  |  90%
# libkml-1.3.0         | 4.1 MB    | #########3 |  94%
# libkml-1.3.0         | 4.1 MB    | #########7 |  97%
# libkml-1.3.0         | 4.1 MB    | ########## | 100%
#
# libllvm9-9.0.1       | 61 KB     |            |   0%
# libllvm9-9.0.1       | 61 KB     | ########## | 100%
# libllvm9-9.0.1       | 61 KB     | ########## | 100%
#
# click-plugins-1.1.1  | 12 KB     |            |   0%
# click-plugins-1.1.1  | 12 KB     | ########## | 100%
#
# pyproj-1.9.6         | 234 KB    |            |   0%
# pyproj-1.9.6         | 234 KB    | #######5   |  75%
# pyproj-1.9.6         | 234 KB    | ########## | 100%
#
# geos-3.7.1           | 771 KB    |            |   0%
# geos-3.7.1           | 771 KB    | ##4        |  25%
# geos-3.7.1           | 771 KB    | ####9      |  50%
# geos-3.7.1           | 771 KB    | #######    |  71%
# geos-3.7.1           | 771 KB    | ########9  |  89%
# geos-3.7.1           | 771 KB    | ########## | 100%
#
# ca-certificates-2021 | 113 KB    |            |   0%
# ca-certificates-2021 | 113 KB    | ########## | 100%
#
# krb5-1.16.4          | 693 KB    |            |   0%
# krb5-1.16.4          | 693 KB    | ###2       |  32%
# krb5-1.16.4          | 693 KB    | ######4    |  65%
# krb5-1.16.4          | 693 KB    | #########  |  90%
# krb5-1.16.4          | 693 KB    | ########## | 100%
#
# curl-7.71.1          | 129 KB    |            |   0%
# curl-7.71.1          | 129 KB    | ########## | 100%
# curl-7.71.1          | 129 KB    | ########## | 100%
#
# gdal-2.3.3           | 991 KB    |            |   0%
# gdal-2.3.3           | 991 KB    | ##         |  21%
# gdal-2.3.3           | 991 KB    | ####       |  40%
# gdal-2.3.3           | 991 KB    | #####6     |  57%
# gdal-2.3.3           | 991 KB    | #######1   |  71%
# gdal-2.3.3           | 991 KB    | ########5  |  86%
# gdal-2.3.3           | 991 KB    | ########## | 100%
# gdal-2.3.3           | 991 KB    | ########## | 100%
#
# certifi-2021.5.30    | 140 KB    |            |   0%
# certifi-2021.5.30    | 140 KB    | ########## | 100%
# certifi-2021.5.30    | 140 KB    | ########## | 100%
#
# munch-2.5.0          | 15 KB     |            |   0%
# munch-2.5.0          | 15 KB     | ########## | 100%
#
# libpq-11.2           | 2.6 MB    |            |   0%
# libpq-11.2           | 2.6 MB    | 8          |   9%
# libpq-11.2           | 2.6 MB    | #7         |  17%
# libpq-11.2           | 2.6 MB    | ##3        |  23%
# libpq-11.2           | 2.6 MB    | ##8        |  29%
# libpq-11.2           | 2.6 MB    | ###3       |  34%
# libpq-11.2           | 2.6 MB    | ###9       |  39%
# libpq-11.2           | 2.6 MB    | ####4      |  45%
# libpq-11.2           | 2.6 MB    | #####      |  50%
# libpq-11.2           | 2.6 MB    | #####5     |  55%
# libpq-11.2           | 2.6 MB    | ######     |  61%
# libpq-11.2           | 2.6 MB    | ######6    |  66%
# libpq-11.2           | 2.6 MB    | #######    |  71%
# libpq-11.2           | 2.6 MB    | #######6   |  76%
# libpq-11.2           | 2.6 MB    | ########1  |  81%
# libpq-11.2           | 2.6 MB    | ########5  |  86%
# libpq-11.2           | 2.6 MB    | #########  |  91%
# libpq-11.2           | 2.6 MB    | #########5 |  96%
# libpq-11.2           | 2.6 MB    | ########## | 100%
#
# shapely-1.6.4        | 285 KB    |            |   0%
# shapely-1.6.4        | 285 KB    | #######2   |  73%
# shapely-1.6.4        | 285 KB    | ########## | 100%
#
# fiona-1.8.4          | 621 KB    |            |   0%
# fiona-1.8.4          | 621 KB    | ###3       |  33%
# fiona-1.8.4          | 621 KB    | ######4    |  64%
# fiona-1.8.4          | 621 KB    | #########  |  90%
# fiona-1.8.4          | 621 KB    | ########## | 100%
#
# anaconda-custom      | 36 KB     |            |   0%
# anaconda-custom      | 36 KB     | ########## | 100%
#
# proj4-5.2.0          | 3.1 MB    |            |   0%
# proj4-5.2.0          | 3.1 MB    | 7          |   7%
# proj4-5.2.0          | 3.1 MB    | #3         |  14%
# proj4-5.2.0          | 3.1 MB    | #8         |  19%
# proj4-5.2.0          | 3.1 MB    | ##3        |  24%
# proj4-5.2.0          | 3.1 MB    | ##8        |  28%
# proj4-5.2.0          | 3.1 MB    | ###2       |  33%
# proj4-5.2.0          | 3.1 MB    | ###6       |  37%
# proj4-5.2.0          | 3.1 MB    | ####       |  41%
# proj4-5.2.0          | 3.1 MB    | ####5      |  45%
# proj4-5.2.0          | 3.1 MB    | ####9      |  49%
# proj4-5.2.0          | 3.1 MB    | #####3     |  54%
# proj4-5.2.0          | 3.1 MB    | #####8     |  58%
# proj4-5.2.0          | 3.1 MB    | ######2    |  62%
# proj4-5.2.0          | 3.1 MB    | ######6    |  67%
# proj4-5.2.0          | 3.1 MB    | #######    |  71%
# proj4-5.2.0          | 3.1 MB    | #######5   |  75%
# proj4-5.2.0          | 3.1 MB    | #######9   |  80%
# proj4-5.2.0          | 3.1 MB    | ########3  |  84%
# proj4-5.2.0          | 3.1 MB    | ########8  |  88%
# proj4-5.2.0          | 3.1 MB    | #########2 |  92%
# proj4-5.2.0          | 3.1 MB    | #########6 |  96%
# proj4-5.2.0          | 3.1 MB    | ########## | 100%
# proj4-5.2.0          | 3.1 MB    | ########## | 100%
#
# snappy-1.1.8         | 80 KB     |            |   0%
# snappy-1.1.8         | 80 KB     | ########## | 100%
# snappy-1.1.8         | 80 KB     | ########## | 100%
#
# conda-4.10.3         | 2.9 MB    |            |   0%
# conda-4.10.3         | 2.9 MB    | 7          |   7%
# conda-4.10.3         | 2.9 MB    | #4         |  14%
# conda-4.10.3         | 2.9 MB    | #9         |  20%
# conda-4.10.3         | 2.9 MB    | ##5        |  25%
# conda-4.10.3         | 2.9 MB    | ##9        |  30%
# conda-4.10.3         | 2.9 MB    | ###4       |  35%
# conda-4.10.3         | 2.9 MB    | ###9       |  39%
# conda-4.10.3         | 2.9 MB    | ####4      |  44%
# conda-4.10.3         | 2.9 MB    | ####8      |  48%
# conda-4.10.3         | 2.9 MB    | #####2     |  53%
# conda-4.10.3         | 2.9 MB    | #####7     |  58%
# conda-4.10.3         | 2.9 MB    | ######2    |  62%
# conda-4.10.3         | 2.9 MB    | ######6    |  67%
# conda-4.10.3         | 2.9 MB    | #######1   |  71%
# conda-4.10.3         | 2.9 MB    | #######6   |  76%
# conda-4.10.3         | 2.9 MB    | ########   |  81%
# conda-4.10.3         | 2.9 MB    | ########5  |  86%
# conda-4.10.3         | 2.9 MB    | ########9  |  90%
# conda-4.10.3         | 2.9 MB    | #########4 |  95%
# conda-4.10.3         | 2.9 MB    | #########9 | 100%
# conda-4.10.3         | 2.9 MB    | ########## | 100%
#
# libboost-1.73.0      | 20.3 MB   |            |   0%
# libboost-1.73.0      | 20.3 MB   |            |   1%
# libboost-1.73.0      | 20.3 MB   | 1          |   2%
# libboost-1.73.0      | 20.3 MB   | 2          |   3%
# libboost-1.73.0      | 20.3 MB   | 3          |   3%
# libboost-1.73.0      | 20.3 MB   | 4          |   4%
# libboost-1.73.0      | 20.3 MB   | 4          |   5%
# libboost-1.73.0      | 20.3 MB   | 5          |   5%
# libboost-1.73.0      | 20.3 MB   | 6          |   6%
# libboost-1.73.0      | 20.3 MB   | 6          |   7%
# libboost-1.73.0      | 20.3 MB   | 7          |   8%
# libboost-1.73.0      | 20.3 MB   | 8          |   8%
# libboost-1.73.0      | 20.3 MB   | 8          |   9%
# libboost-1.73.0      | 20.3 MB   | 9          |   9%
# libboost-1.73.0      | 20.3 MB   | #          |  10%
# libboost-1.73.0      | 20.3 MB   | #          |  11%
# libboost-1.73.0      | 20.3 MB   | #1         |  11%
# libboost-1.73.0      | 20.3 MB   | #2         |  12%
# libboost-1.73.0      | 20.3 MB   | #2         |  13%
# libboost-1.73.0      | 20.3 MB   | #3         |  13%
# libboost-1.73.0      | 20.3 MB   | #4         |  14%
# libboost-1.73.0      | 20.3 MB   | #4         |  15%
# libboost-1.73.0      | 20.3 MB   | #5         |  15%
# libboost-1.73.0      | 20.3 MB   | #6         |  16%
# libboost-1.73.0      | 20.3 MB   | #6         |  17%
# libboost-1.73.0      | 20.3 MB   | #7         |  17%
# libboost-1.73.0      | 20.3 MB   | #7         |  18%
# libboost-1.73.0      | 20.3 MB   | #8         |  19%
# libboost-1.73.0      | 20.3 MB   | #9         |  19%
# libboost-1.73.0      | 20.3 MB   | #9         |  20%
# libboost-1.73.0      | 20.3 MB   | ##         |  21%
# libboost-1.73.0      | 20.3 MB   | ##1        |  21%
# libboost-1.73.0      | 20.3 MB   | ##1        |  22%
# libboost-1.73.0      | 20.3 MB   | ##2        |  23%
# libboost-1.73.0      | 20.3 MB   | ##3        |  23%
# libboost-1.73.0      | 20.3 MB   | ##3        |  24%
# libboost-1.73.0      | 20.3 MB   | ##4        |  24%
# libboost-1.73.0      | 20.3 MB   | ##5        |  25%
# libboost-1.73.0      | 20.3 MB   | ##5        |  26%
# libboost-1.73.0      | 20.3 MB   | ##6        |  26%
# libboost-1.73.0      | 20.3 MB   | ##7        |  27%
# libboost-1.73.0      | 20.3 MB   | ##7        |  28%
# libboost-1.73.0      | 20.3 MB   | ##8        |  28%
# libboost-1.73.0      | 20.3 MB   | ##9        |  29%
# libboost-1.73.0      | 20.3 MB   | ##9        |  30%
# libboost-1.73.0      | 20.3 MB   | ###        |  30%
# libboost-1.73.0      | 20.3 MB   | ###        |  31%
# libboost-1.73.0      | 20.3 MB   | ###1       |  32%
# libboost-1.73.0      | 20.3 MB   | ###2       |  32%
# libboost-1.73.0      | 20.3 MB   | ###2       |  33%
# libboost-1.73.0      | 20.3 MB   | ###3       |  34%
# libboost-1.73.0      | 20.3 MB   | ###4       |  34%
# libboost-1.73.0      | 20.3 MB   | ###4       |  35%
# libboost-1.73.0      | 20.3 MB   | ###5       |  36%
# libboost-1.73.0      | 20.3 MB   | ###6       |  36%
# libboost-1.73.0      | 20.3 MB   | ###6       |  37%
# libboost-1.73.0      | 20.3 MB   | ###7       |  38%
# libboost-1.73.0      | 20.3 MB   | ###8       |  38%
# libboost-1.73.0      | 20.3 MB   | ###8       |  39%
# libboost-1.73.0      | 20.3 MB   | ###9       |  40%
# libboost-1.73.0      | 20.3 MB   | ####       |  40%
# libboost-1.73.0      | 20.3 MB   | ####       |  41%
# libboost-1.73.0      | 20.3 MB   | ####1      |  41%
# libboost-1.73.0      | 20.3 MB   | ####1      |  42%
# libboost-1.73.0      | 20.3 MB   | ####2      |  43%
# libboost-1.73.0      | 20.3 MB   | ####3      |  44%
# libboost-1.73.0      | 20.3 MB   | ####4      |  44%
# libboost-1.73.0      | 20.3 MB   | ####5      |  45%
# libboost-1.73.0      | 20.3 MB   | ####5      |  46%
# libboost-1.73.0      | 20.3 MB   | ####6      |  46%
# libboost-1.73.0      | 20.3 MB   | ####7      |  47%
# libboost-1.73.0      | 20.3 MB   | ####7      |  48%
# libboost-1.73.0      | 20.3 MB   | ####8      |  49%
# libboost-1.73.0      | 20.3 MB   | ####9      |  49%
# libboost-1.73.0      | 20.3 MB   | ####9      |  50%
# libboost-1.73.0      | 20.3 MB   | #####      |  50%
# libboost-1.73.0      | 20.3 MB   | #####1     |  51%
# libboost-1.73.0      | 20.3 MB   | #####1     |  52%
# libboost-1.73.0      | 20.3 MB   | #####2     |  52%
# libboost-1.73.0      | 20.3 MB   | #####3     |  53%
# libboost-1.73.0      | 20.3 MB   | #####3     |  54%
# libboost-1.73.0      | 20.3 MB   | #####4     |  54%
# libboost-1.73.0      | 20.3 MB   | #####5     |  55%
# libboost-1.73.0      | 20.3 MB   | #####5     |  56%
# libboost-1.73.0      | 20.3 MB   | #####6     |  56%
# libboost-1.73.0      | 20.3 MB   | #####7     |  57%
# libboost-1.73.0      | 20.3 MB   | #####7     |  58%
# libboost-1.73.0      | 20.3 MB   | #####8     |  58%
# libboost-1.73.0      | 20.3 MB   | #####9     |  59%
# libboost-1.73.0      | 20.3 MB   | #####9     |  60%
# libboost-1.73.0      | 20.3 MB   | ######     |  60%
# libboost-1.73.0      | 20.3 MB   | ######     |  61%
# libboost-1.73.0      | 20.3 MB   | ######1    |  62%
# libboost-1.73.0      | 20.3 MB   | ######2    |  62%
# libboost-1.73.0      | 20.3 MB   | ######2    |  63%
# libboost-1.73.0      | 20.3 MB   | ######3    |  64%
# libboost-1.73.0      | 20.3 MB   | ######4    |  64%
# libboost-1.73.0      | 20.3 MB   | ######4    |  65%
# libboost-1.73.0      | 20.3 MB   | ######5    |  65%
# libboost-1.73.0      | 20.3 MB   | ######6    |  66%
# libboost-1.73.0      | 20.3 MB   | ######6    |  67%
# libboost-1.73.0      | 20.3 MB   | ######7    |  67%
# libboost-1.73.0      | 20.3 MB   | ######8    |  68%
# libboost-1.73.0      | 20.3 MB   | ######8    |  69%
# libboost-1.73.0      | 20.3 MB   | ######9    |  69%
# libboost-1.73.0      | 20.3 MB   | #######    |  70%
# libboost-1.73.0      | 20.3 MB   | #######    |  71%
# libboost-1.73.0      | 20.3 MB   | #######1   |  71%
# libboost-1.73.0      | 20.3 MB   | #######2   |  72%
# libboost-1.73.0      | 20.3 MB   | #######2   |  73%
# libboost-1.73.0      | 20.3 MB   | #######3   |  73%
# libboost-1.73.0      | 20.3 MB   | #######4   |  74%
# libboost-1.73.0      | 20.3 MB   | #######4   |  75%
# libboost-1.73.0      | 20.3 MB   | #######5   |  75%
# libboost-1.73.0      | 20.3 MB   | #######5   |  76%
# libboost-1.73.0      | 20.3 MB   | #######6   |  77%
# libboost-1.73.0      | 20.3 MB   | #######7   |  77%
# libboost-1.73.0      | 20.3 MB   | #######7   |  78%
# libboost-1.73.0      | 20.3 MB   | #######8   |  79%
# libboost-1.73.0      | 20.3 MB   | #######9   |  79%
# libboost-1.73.0      | 20.3 MB   | #######9   |  80%
# libboost-1.73.0      | 20.3 MB   | ########   |  81%
# libboost-1.73.0      | 20.3 MB   | ########1  |  81%
# libboost-1.73.0      | 20.3 MB   | ########1  |  82%
# libboost-1.73.0      | 20.3 MB   | ########2  |  83%
# libboost-1.73.0      | 20.3 MB   | ########3  |  83%
# libboost-1.73.0      | 20.3 MB   | ########3  |  84%
# libboost-1.73.0      | 20.3 MB   | ########4  |  85%
# libboost-1.73.0      | 20.3 MB   | ########5  |  85%
# libboost-1.73.0      | 20.3 MB   | ########5  |  86%
# libboost-1.73.0      | 20.3 MB   | ########6  |  86%
# libboost-1.73.0      | 20.3 MB   | ########7  |  87%
# libboost-1.73.0      | 20.3 MB   | ########7  |  88%
# libboost-1.73.0      | 20.3 MB   | ########8  |  88%
# libboost-1.73.0      | 20.3 MB   | ########9  |  89%
# libboost-1.73.0      | 20.3 MB   | ########9  |  90%
# libboost-1.73.0      | 20.3 MB   | #########  |  90%
# libboost-1.73.0      | 20.3 MB   | #########  |  91%
# libboost-1.73.0      | 20.3 MB   | #########1 |  92%
# libboost-1.73.0      | 20.3 MB   | #########2 |  92%
# libboost-1.73.0      | 20.3 MB   | #########2 |  93%
# libboost-1.73.0      | 20.3 MB   | #########3 |  94%
# libboost-1.73.0      | 20.3 MB   | #########4 |  94%
# libboost-1.73.0      | 20.3 MB   | #########4 |  95%
# libboost-1.73.0      | 20.3 MB   | #########5 |  96%
# libboost-1.73.0      | 20.3 MB   | #########6 |  96%
# libboost-1.73.0      | 20.3 MB   | #########6 |  97%
# libboost-1.73.0      | 20.3 MB   | #########7 |  98%
# libboost-1.73.0      | 20.3 MB   | #########8 |  98%
# libboost-1.73.0      | 20.3 MB   | #########8 |  99%
# libboost-1.73.0      | 20.3 MB   | #########9 |  99%
# libboost-1.73.0      | 20.3 MB   | ########## | 100%
#
# mpc-1.1.0            | 260 KB    |            |   0%
# mpc-1.1.0            | 260 KB    | #####5     |  55%
# mpc-1.1.0            | 260 KB    | ########## | 100%
#
# libnetcdf-4.6.1      | 494 KB    |            |   0%
# libnetcdf-4.6.1      | 494 KB    | ####5      |  45%
# libnetcdf-4.6.1      | 494 KB    | ########7  |  87%
# libnetcdf-4.6.1      | 494 KB    | ########## | 100%
#
# expat-2.4.1          | 201 KB    |            |   0%
# expat-2.4.1          | 201 KB    | ########## | 100%
# expat-2.4.1          | 201 KB    | ########## | 100%
#
# geopandas-0.6.1      | 871 KB    |            |   0%
# geopandas-0.6.1      | 871 KB    | ##2        |  22%
# geopandas-0.6.1      | 871 KB    | ####2      |  42%
# geopandas-0.6.1      | 871 KB    | #####8     |  59%
# geopandas-0.6.1      | 871 KB    | #######5   |  75%
# geopandas-0.6.1      | 871 KB    | #########1 |  92%
# geopandas-0.6.1      | 871 KB    | ########## | 100%
#
# gmpy2-2.0.8          | 145 KB    |            |   0%
# gmpy2-2.0.8          | 145 KB    | ########## | 100%
# gmpy2-2.0.8          | 145 KB    | ########## | 100%
#
# cligj-0.7.2          | 14 KB     |            |   0%
# cligj-0.7.2          | 14 KB     | ########## | 100%
#
# kealib-1.4.7         | 133 KB    |            |   0%
# kealib-1.4.7         | 133 KB    | ########## | 100%
# kealib-1.4.7         | 133 KB    | ########## | 100%
#
# mpir-3.0.0           | 1.3 MB    |            |   0%
# mpir-3.0.0           | 1.3 MB    | #5         |  16%
# mpir-3.0.0           | 1.3 MB    | ###1       |  31%
# mpir-3.0.0           | 1.3 MB    | ####3      |  43%
# mpir-3.0.0           | 1.3 MB    | #####4     |  54%
# mpir-3.0.0           | 1.3 MB    | ######5    |  65%
# mpir-3.0.0           | 1.3 MB    | #######6   |  76%
# mpir-3.0.0           | 1.3 MB    | ########6  |  87%
# mpir-3.0.0           | 1.3 MB    | #########7 |  98%
# mpir-3.0.0           | 1.3 MB    | ########## | 100%
#
# hdf4-4.2.13          | 1.3 MB    |            |   0%
# hdf4-4.2.13          | 1.3 MB    | #1         |  12%
# hdf4-4.2.13          | 1.3 MB    | ##5        |  25%
# hdf4-4.2.13          | 1.3 MB    | ###8       |  38%
# hdf4-4.2.13          | 1.3 MB    | ####8      |  49%
# hdf4-4.2.13          | 1.3 MB    | #####9     |  59%
# hdf4-4.2.13          | 1.3 MB    | ######9    |  70%
# hdf4-4.2.13          | 1.3 MB    | #######9   |  80%
# hdf4-4.2.13          | 1.3 MB    | #########  |  90%
# hdf4-4.2.13          | 1.3 MB    | ########## | 100%
# hdf4-4.2.13          | 1.3 MB    | ########## | 100%
#
# libspatialite-4.3.0a | 2.3 MB    |            |   0%
# libspatialite-4.3.0a | 2.3 MB    | 6          |   6%
# libspatialite-4.3.0a | 2.3 MB    | #4         |  15%
# libspatialite-4.3.0a | 2.3 MB    | ##2        |  22%
# libspatialite-4.3.0a | 2.3 MB    | ##8        |  28%
# libspatialite-4.3.0a | 2.3 MB    | ###4       |  35%
# libspatialite-4.3.0a | 2.3 MB    | ####       |  41%
# libspatialite-4.3.0a | 2.3 MB    | ####6      |  47%
# libspatialite-4.3.0a | 2.3 MB    | #####2     |  52%
# libspatialite-4.3.0a | 2.3 MB    | #####7     |  58%
# libspatialite-4.3.0a | 2.3 MB    | ######3    |  63%
# libspatialite-4.3.0a | 2.3 MB    | ######8    |  69%
# libspatialite-4.3.0a | 2.3 MB    | #######3   |  74%
# libspatialite-4.3.0a | 2.3 MB    | #######9   |  79%
# libspatialite-4.3.0a | 2.3 MB    | ########4  |  85%
# libspatialite-4.3.0a | 2.3 MB    | #########  |  91%
# libspatialite-4.3.0a | 2.3 MB    | #########6 |  96%
# libspatialite-4.3.0a | 2.3 MB    | ########## | 100%
#
# libgdal-2.3.3        | 7.2 MB    |            |   0%
# libgdal-2.3.3        | 7.2 MB    | 1          |   2%
# libgdal-2.3.3        | 7.2 MB    | 4          |   5%
# libgdal-2.3.3        | 7.2 MB    | 7          |   7%
# libgdal-2.3.3        | 7.2 MB    | 9          |  10%
# libgdal-2.3.3        | 7.2 MB    | #1         |  11%
# libgdal-2.3.3        | 7.2 MB    | #3         |  13%
# libgdal-2.3.3        | 7.2 MB    | #5         |  15%
# libgdal-2.3.3        | 7.2 MB    | #7         |  17%
# libgdal-2.3.3        | 7.2 MB    | #9         |  19%
# libgdal-2.3.3        | 7.2 MB    | ##1        |  21%
# libgdal-2.3.3        | 7.2 MB    | ##2        |  23%
# libgdal-2.3.3        | 7.2 MB    | ##4        |  25%
# libgdal-2.3.3        | 7.2 MB    | ##6        |  26%
# libgdal-2.3.3        | 7.2 MB    | ##7        |  28%
# libgdal-2.3.3        | 7.2 MB    | ##9        |  30%
# libgdal-2.3.3        | 7.2 MB    | ###1       |  32%
# libgdal-2.3.3        | 7.2 MB    | ###3       |  33%
# libgdal-2.3.3        | 7.2 MB    | ###5       |  35%
# libgdal-2.3.3        | 7.2 MB    | ###7       |  37%
# libgdal-2.3.3        | 7.2 MB    | ###9       |  39%
# libgdal-2.3.3        | 7.2 MB    | ####       |  41%
# libgdal-2.3.3        | 7.2 MB    | ####2      |  43%
# libgdal-2.3.3        | 7.2 MB    | ####4      |  45%
# libgdal-2.3.3        | 7.2 MB    | ####6      |  47%
# libgdal-2.3.3        | 7.2 MB    | ####8      |  48%
# libgdal-2.3.3        | 7.2 MB    | #####      |  50%
# libgdal-2.3.3        | 7.2 MB    | #####2     |  52%
# libgdal-2.3.3        | 7.2 MB    | #####4     |  54%
# libgdal-2.3.3        | 7.2 MB    | #####5     |  56%
# libgdal-2.3.3        | 7.2 MB    | #####7     |  57%
# libgdal-2.3.3        | 7.2 MB    | #####9     |  59%
# libgdal-2.3.3        | 7.2 MB    | ######     |  61%
# libgdal-2.3.3        | 7.2 MB    | ######2    |  63%
# libgdal-2.3.3        | 7.2 MB    | ######4    |  65%
# libgdal-2.3.3        | 7.2 MB    | ######6    |  66%
# libgdal-2.3.3        | 7.2 MB    | ######8    |  68%
# libgdal-2.3.3        | 7.2 MB    | ######9    |  70%
# libgdal-2.3.3        | 7.2 MB    | #######1   |  72%
# libgdal-2.3.3        | 7.2 MB    | #######3   |  74%
# libgdal-2.3.3        | 7.2 MB    | #######5   |  76%
# libgdal-2.3.3        | 7.2 MB    | #######7   |  77%
# libgdal-2.3.3        | 7.2 MB    | #######9   |  79%
# libgdal-2.3.3        | 7.2 MB    | ########1  |  81%
# libgdal-2.3.3        | 7.2 MB    | ########3  |  83%
# libgdal-2.3.3        | 7.2 MB    | ########4  |  85%
# libgdal-2.3.3        | 7.2 MB    | ########6  |  87%
# libgdal-2.3.3        | 7.2 MB    | ########8  |  88%
# libgdal-2.3.3        | 7.2 MB    | #########  |  90%
# libgdal-2.3.3        | 7.2 MB    | #########2 |  92%
# libgdal-2.3.3        | 7.2 MB    | #########4 |  94%
# libgdal-2.3.3        | 7.2 MB    | #########5 |  96%
# libgdal-2.3.3        | 7.2 MB    | #########7 |  98%
# libgdal-2.3.3        | 7.2 MB    | #########9 | 100%
# libgdal-2.3.3        | 7.2 MB    | ########## | 100%
#
# libcurl-7.71.1       | 275 KB    |            |   0%
# libcurl-7.71.1       | 275 KB    | ####6      |  47%
# libcurl-7.71.1       | 275 KB    | ########## | 100%
# libcurl-7.71.1       | 275 KB    | ########## | 100%
#
# mpfr-4.0.2           | 1.5 MB    |            |   0%
# mpfr-4.0.2           | 1.5 MB    | #2         |  12%
# mpfr-4.0.2           | 1.5 MB    | ##3        |  24%
# mpfr-4.0.2           | 1.5 MB    | ###3       |  34%
# mpfr-4.0.2           | 1.5 MB    | ####3      |  43%
# mpfr-4.0.2           | 1.5 MB    | #####1     |  51%
# mpfr-4.0.2           | 1.5 MB    | ######4    |  65%
# mpfr-4.0.2           | 1.5 MB    | #######4   |  74%
# mpfr-4.0.2           | 1.5 MB    | ########3  |  83%
# mpfr-4.0.2           | 1.5 MB    | #########2 |  93%
# mpfr-4.0.2           | 1.5 MB    | ########## | 100%
#
# openssl-1.1.1k       | 4.8 MB    |            |   0%
# openssl-1.1.1k       | 4.8 MB    | 3          |   4%
# openssl-1.1.1k       | 4.8 MB    | 7          |   7%
# openssl-1.1.1k       | 4.8 MB    | #          |  11%
# openssl-1.1.1k       | 4.8 MB    | #3         |  14%
# openssl-1.1.1k       | 4.8 MB    | #6         |  17%
# openssl-1.1.1k       | 4.8 MB    | #9         |  20%
# openssl-1.1.1k       | 4.8 MB    | ##2        |  23%
# openssl-1.1.1k       | 4.8 MB    | ##5        |  26%
# openssl-1.1.1k       | 4.8 MB    | ##8        |  29%
# openssl-1.1.1k       | 4.8 MB    | ###1       |  31%
# openssl-1.1.1k       | 4.8 MB    | ###4       |  34%
# openssl-1.1.1k       | 4.8 MB    | ###6       |  37%
# openssl-1.1.1k       | 4.8 MB    | ###9       |  40%
# openssl-1.1.1k       | 4.8 MB    | ####2      |  42%
# openssl-1.1.1k       | 4.8 MB    | ####5      |  45%
# openssl-1.1.1k       | 4.8 MB    | ####7      |  48%
# openssl-1.1.1k       | 4.8 MB    | #####      |  51%
# openssl-1.1.1k       | 4.8 MB    | #####3     |  53%
# openssl-1.1.1k       | 4.8 MB    | #####6     |  56%
# openssl-1.1.1k       | 4.8 MB    | #####8     |  59%
# openssl-1.1.1k       | 4.8 MB    | ######1    |  62%
# openssl-1.1.1k       | 4.8 MB    | ######4    |  64%
# openssl-1.1.1k       | 4.8 MB    | ######7    |  67%
# openssl-1.1.1k       | 4.8 MB    | ######9    |  70%
# openssl-1.1.1k       | 4.8 MB    | #######2   |  73%
# openssl-1.1.1k       | 4.8 MB    | #######5   |  75%
# openssl-1.1.1k       | 4.8 MB    | #######8   |  78%
# openssl-1.1.1k       | 4.8 MB    | ########   |  81%
# openssl-1.1.1k       | 4.8 MB    | ########3  |  83%
# openssl-1.1.1k       | 4.8 MB    | ########6  |  86%
# openssl-1.1.1k       | 4.8 MB    | ########8  |  89%
# openssl-1.1.1k       | 4.8 MB    | #########1 |  91%
# openssl-1.1.1k       | 4.8 MB    | #########4 |  94%
# openssl-1.1.1k       | 4.8 MB    | #########7 |  97%
# openssl-1.1.1k       | 4.8 MB    | ########## | 100%
# openssl-1.1.1k       | 4.8 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# !pip install openpyxl
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
# Out:
# Requirement already satisfied: openpyxl in c:\users\acer\anaconda3\lib\site-packages (3.0.5)
# Requirement already satisfied: et-xmlfile in c:\users\acer\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in c:\users\acer\anaconda3\lib\site-packages (from openpyxl) (1.4.1)

# %% [markdown]
# ### Importing our shape file and our data

# %%
df = pd.read_excel('D:/Forest.xlsx')
shp_gdf = gpd.read_file('D:/Indian_states.shp')

# %%
df.head(40)
# Out:
#                State/UTs Geographical area Very dense forest  \
# 0         Andhra Pradesh          1,62,968             1,994
# 1      Arunachal Pradesh            83,743            21,095
# 2                  Assam            78,438             2,795
# 3                  Bihar            94,163               333
# 4           Chhattisgarh          1,35,192             7,068
# 5                  Delhi             1,483              6.72
# 6                    Goa             3,702               538
# 7                Gujarat          1,96,244               378
# 8                Haryana            44,212                28
# 9       Himachal Pradesh            55,673             3,113
# 10       Jammu & Kashmir          2,22,236             4,281
# 11             Jharkhand            79,716             2,603
# 12             Karnataka          1,91,791             4,501
# 13                Kerala            38,852             1,935
# 14        Madhya Pradesh          3,08,252             6,676
# 15           Maharashtra          3,07,713             8,721
# 16               Manipur            22,327               905
# 17             Meghalaya            22,429               489
# 18               Mizoram            21,081               157
# 19              Nagaland            16,579             1,273
# 20                Odisha          1,55,707             6,970
# 21                Punjab            50,362                 8
# 22             Rajasthan          3,42,239                78
# 23                Sikkim             7,096             1,102
# 24            Tamil Nadu          1,30,060             3,605
# 25             Telangana          1,12,077             1,608
# 26               Tripura            10,486               654
# 27         Uttar Pradesh          2,40,928             2,617
# 28           Uttarakhand            53,483             5,047
# 29           West Bengal            88,752             3,019
# 30         A & N Islands             8,249             5,678
# 31            Chandigarh               114              1.36
# 32  Dadra & Nagar Haveli               491                 0
# 33           Daman & Diu               111              1.40
# 34           Lakshadweep                30                 0
# 35            Puducherry               490                 0
# 36           Grand Total         32,87,469            99,278
#
#    Mod. dense forest Open forest Total forest  \
# 0             13,938      13,205       29,137
# 1             30,557      15,036       66,688
# 2             10,279      15,253       28,327
# 3              3,280       3,693        7,306
# 4             32,198      16,345       55,611
# 5              56.42      132.30       195.44
# 6                576       1,123        2,237
# 7              5,092       9,387       14,857
# 8                451       1,123        1,602
# 9              7,126       5,195       15,434
# 10             8,612      10,719       23,612
# 11             9,687      11,321       23,611
# 12            21,048      13,026       38,575
# 13             9,508       9,701       21,144
# 14            34,341      36,465       77,482
# 15            20,572      21,485       50,778
# 16             6,386       9,556       16,847
# 17             9,267       7,363       17,119
# 18             5,801      12,048       18,006
# 19             4,534       6,679       12,486
# 20            21,552      23,097       51,619
# 21               801       1,040        1,849
# 22             4,342      12,210       16,630
# 23             1,552         688        3,342
# 24            11,030      11,729       26,364
# 25             8,787      10,187       20,582
# 26             5,236       1,836        7,726
# 27             4,080       8,109       14,806
# 28            12,805       6,451       24,303
# 29             4,160       9,723       16,902
# 30               684         381        6,743
# 31             14.24        6.43        22.03
# 32                80         127          207
# 33              5.69       13.40        20.49
# 34             16.09       11.01        27.10
# 35             17.66       34.75        52.41
# 36          3,08,472    3,04,499     7,12,249
#
#     Percentage of geographical area   Scrub
# 0                             17.88   8,255
# 1                             79.63     229
# 2                             36.11     173
# 3                              7.76     250
# 4                             41.13     610
# 5                             13.18    0.30
# 6                             60.43       0
# 7                              7.57   2,994
# 8                              3.62     154
# 9                             27.72     315
# 10                            10.62     548
# 11                            29.62     688
# 12                            20.11   4,484
# 13                            54.42      13
# 14                            25.14   6,002
# 15                            16.50   4,256
# 16                            75.46   1,181
# 17                            76.33     600
# 18                            85.41       1
# 19                            75.31     635
# 20                            33.15   4,327
# 21                             3.67      33
# 22                             4.86   4,760
# 23                            47.10     307
# 24                            20.27     715
# 25                            18.36   3,615
# 26                            73.68      29
# 27                             6.15     587
# 28                            45.44     383
# 29                            19.04     146
# 30                            81.74       1
# 31                            19.32    0.10
# 32                            42.16       5
# 33                            18.46    0.19
# 34                            90.33    0.00
# 35                            10.70    0.00
# 36                            21.67  46,297

# %% [markdown]
# #### Renaming the states in our dataset to match the shape file

# %%
df1 = df[['State/UTs', 'Percentage of geographical area']]
df1['State/UTs'][30] = 'Andaman & Nicobar Island'
df1['State/UTs'][1] = 'Arunanchal Pradesh'
df1['State/UTs'][32] = 'Dadara & Nagar Havelli'
df1['State/UTs'][5] = 'NCT of Delhi'
# Out:
# <ipython-input-9-68dfe9cf1d6c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State/UTs'][30] = 'Andaman & Nicobar Island'
# C:\Users\acer\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-9-68dfe9cf1d6c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State/UTs'][1] = 'Arunanchal Pradesh'
# <ipython-input-9-68dfe9cf1d6c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State/UTs'][32] = 'Dadara & Nagar Havelli'
# <ipython-input-9-68dfe9cf1d6c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State/UTs'][5] = 'NCT of Delhi'

# %%
merged = shp_gdf.set_index('st_nm').join(df1.set_index('State/UTs'))
merged.head(40)
# Out:
#                                                                    geometry  \
# st_nm
# Andaman & Nicobar Island  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Arunanchal Pradesh        POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# Assam                     MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# Bihar                     MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# Chandigarh                POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# Chhattisgarh              POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# Dadara & Nagar Havelli    POLYGON ((73.20657 20.12216, 73.20797 20.10650...
# Daman & Diu               MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...
# Goa                       MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# Gujarat                   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# Haryana                   POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# Himachal Pradesh          POLYGON ((76.79634 33.25490, 76.80351 33.25275...
# Jammu & Kashmir           POLYGON ((74.73451 37.02068, 74.73647 37.01937...
# Jharkhand                 POLYGON ((87.60582 25.31512, 87.61279 25.31184...
# Karnataka                 MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...
# Kerala                    POLYGON ((74.99575 12.79227, 75.00006 12.78777...
# Lakshadweep               MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...
# Madhya Pradesh            MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...
# Maharashtra               MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...
# Manipur                   POLYGON ((94.57602 25.64221, 94.57487 25.63858...
# Meghalaya                 POLYGON ((91.85632 26.10353, 91.86717 26.09906...
# Mizoram                   POLYGON ((92.80022 24.41630, 92.80310 24.41603...
# Nagaland                  POLYGON ((95.21458 26.93095, 95.21719 26.92818...
# NCT of Delhi              POLYGON ((77.09361 28.86940, 77.10973 28.86722...
# Puducherry                MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...
# Punjab                    POLYGON ((75.88469 32.48841, 75.90303 32.47169...
# Rajasthan                 POLYGON ((73.89849 29.97896, 73.90021 29.97140...
# Sikkim                    POLYGON ((88.65381 28.09883, 88.66265 28.08956...
# Tamil Nadu                MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...
# Telangana                 POLYGON ((81.05614 17.79097, 81.05834 17.75464...
# Tripura                   POLYGON ((92.22108 24.50131, 92.22771 24.49862...
# Uttar Pradesh             MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...
# Uttarakhand               POLYGON ((79.21047 31.34846, 79.21386 31.34680...
# West Bengal               MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# Odisha                    MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...
# Andhra Pradesh            MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
#
#                           Percentage of geographical area
# st_nm
# Andaman & Nicobar Island                            81.74
# Arunanchal Pradesh                                  79.63
# Assam                                               36.11
# Bihar                                                7.76
# Chandigarh                                          19.32
# Chhattisgarh                                        41.13
# Dadara & Nagar Havelli                              42.16
# Daman & Diu                                         18.46
# Goa                                                 60.43
# Gujarat                                              7.57
# Haryana                                              3.62
# Himachal Pradesh                                    27.72
# Jammu & Kashmir                                     10.62
# Jharkhand                                           29.62
# Karnataka                                           20.11
# Kerala                                              54.42
# Lakshadweep                                         90.33
# Madhya Pradesh                                      25.14
# Maharashtra                                         16.50
# Manipur                                             75.46
# Meghalaya                                           76.33
# Mizoram                                             85.41
# Nagaland                                            75.31
# NCT of Delhi                                        13.18
# Puducherry                                          10.70
# Punjab                                               3.67
# Rajasthan                                            4.86
# Sikkim                                              47.10
# Tamil Nadu                                          20.27
# Telangana                                           18.36
# Tripura                                             73.68
# Uttar Pradesh                                        6.15
# Uttarakhand                                         45.44
# West Bengal                                         19.04
# Odisha                                              33.15
# Andhra Pradesh                                      17.88

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))
ax.axis('off')
ax.set_title('Percentage of Forest Coverage as of 2019',
             fontdict={'fontsize': '20', 'fontweight' : '5'})
fig = merged.plot(column='Percentage of geographical area', cmap='Greens', linewidth=0.5, ax=ax, edgecolor='0.1',legend=True)

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="Percentage of geographical area", y = "State/UTs", data = df1)
# Out:
# <AxesSubplot:xlabel='Percentage of geographical area', ylabel='State/UTs'>
